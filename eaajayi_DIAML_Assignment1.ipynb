# %% [markdown]
# <a href="https://colab.research.google.com/github/ojayedwards01/FirstRepo/blob/master/eaajayi_DIAML_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the required libraries
import numpy as np
import pandas as pd

# %% [markdown]
# Given that 1 meter = 1000 millimeters
#
# The height of Mt. Everest in millimeters = 8848 * 1000 = 8848000 mm
#
# For each fold the thickness of the paper is doubled
#
# So for $n$ number of folds, thickness equals $2^n$

# %%
everest = 8848000

paper_thickness = 1

square = 0

# iterating to get the number of folds higher than Mt. Everest

# while i <

# %%
# Question 3

deposit = 100 #Initial deposit

for i in range(5):
  deposit+=(deposit*0.05) #5% interest on deposit
  print("Deposit at year", i+1,": ", round(deposit)) #Convert the value of deposit to int
  i+=1
# Out:
# Deposit at year 1 :  105
# Deposit at year 2 :  110
# Deposit at year 3 :  116
# Deposit at year 4 :  122
# Deposit at year 5 :  128

# %%
# Question 4
loan_amount = 20000
interest_rate = 1/100 #1 % interest rate

for i in [12,24,36]: #no of months in 3 years
  loan_amount =(loan_amount * ((1+interest_rate)**12))
  # print("Loan amount at the end of year ",i/12," : ", round(loan_amount))
  monthly_repay = loan_amount/i
  print("Monthy repayment rate at the end of year ",i/12," : ", round(monthly_repay))
  i = i+12
# Out:
# Monthy repayment rate at the end of year  1.0  :  1878
# Monthy repayment rate at the end of year  2.0  :  1058
# Monthy repayment rate at the end of year  3.0  :  795

# %%
# Question 5

import pandas as pd
import numpy as np

capital = 100000
customer_base = 100
interest = 0
day = 0
days = [day] # Initialize list of days with value 0
total_interest = [interest] # Initialize list of accumulated interest with value 0


while total_interest[-1] < 100000:
  day+=1
  days.append(day)
  customer_base*=1.01
  interest+= customer_base * 10
  total_interest.append(interest)


# print(days)
# print(total_interest)

interest_data = pd.DataFrame({
    "Day": days,
    "Total Interest": total_interest
})

interest_data
# Out:
#     Day  Total Interest
# 0     0        0.000000
# 1     1     1010.000000
# 2     2     2030.100000
# 3     3     3060.401000
# 4     4     4101.005010
# ..  ...             ...
# 66   66    93774.475459
# 67   67    95722.220213
# 68   68    97689.442415
# 69   69    99676.336840
# 70   70   101683.100208
#
# [71 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# Plot the DataFrame
plt.figure(figsize=(10, 6))
plt.plot(interest_data['Day'], interest_data['Total Interest'], linestyle='-', color='b')

plt.axvline(x=interest_data['Day'].max(), color='r', linestyle='--', linewidth=1, label='End of Period')

# Add titles and labels
plt.title('Amount Over Time')
plt.xlabel('Day')
plt.ylabel('Total Interest ($)')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
# code to upload data files for the project
# from google.colab import files
# uploaded = files.upload()

# %%
# Question 6
ebola_data = pd.read_csv("ebola_download.csv")
ebola_data
# Out:
#         Date  Cases  Death   Diff  Noofdays
# 0   22/03/14     49     29      2         1
# 1   24/03/14     86     59      1         3
# 2   25/03/14     86     60      1         4
# 3   26/03/14     86     62      1         5
# 4   27/03/14    111     72      1         6
# ..       ...    ...    ...    ...       ...
# 75  02/11/14  13014   5191      2       226
# 76  04/11/14  13200   5275      5       228
# 77  09/11/14  14068   5496      2       233
# 78  11/11/14  14383   5492      1       235
# 79  12/11/14  14413   5498 -41955       236
#
# [80 rows x 5 columns]
